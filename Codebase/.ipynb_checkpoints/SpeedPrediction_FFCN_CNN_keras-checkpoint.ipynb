# %% [markdown]
# # Lumo Run - Deep FFCN and CNN

# %% [markdown]
# #### Where is this script being run

# %%
machine_to_run_script = 'local' # 'Sherlock', 'local'
runs_per_file = 'train_loop' # 'single', 'train_loop'

# %% [markdown]
# # Load dependencies

# %%
print('Script is starting!') # these are used for Sherlock to check what is causing the hiccup

import keras
from keras.datasets import mnist
from keras.models import Sequential, load_model, Model
from keras.layers import Dense, Dropout, Conv2D, Conv1D, MaxPooling2D, MaxPooling1D, Flatten, Input, Lambda, Merge
from keras.layers.normalization import BatchNormalization 
from keras.layers.merge import concatenate
from keras.utils import plot_model
from keras import regularizers 
from keras import optimizers
from sklearn.model_selection import GridSearchCV 
from keras.wrappers.scikit_learn import KerasClassifier

print('Successfully loaded keras!')

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats
import tensorflow as tf
from datetime import datetime
from dateutil import tz
from IPython import embed
import time
from time import strftime, gmtime
import socket
import pickle
import os.path
#import dill #can't find dill
import itertools

from pathlib import Path
from sklearn.metrics import confusion_matrix 

# from SpeedPrediction_Helper import *

np.random.seed(7) # Set seed for reproducibility
# Out:
# Script is starting!
# C:\Users\adam\Anaconda3\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.
# Successfully loaded keras!

# %% [markdown]
# #### Set Hyperparameters

# %%
# Data Setup

num_channels = 6 # number of time-series channels of data (i.e. 7 kinematic features) #NOTE: Change to 6 by removing Pelvic Tilt (recommended by Lumo)
num_anthropometrics = 4 # number of user anthropometric data elements
input_window_size = 26 # number of timestamps used in the input for prediction (i.e. the input window)
label_window_size = 20 # number of timestamps used to label the speed we will be predicting
speed_bucket_size = 'none_use_regression' # how to round the data for classification task. Consider '0.5', '0.1', and 'none_use_regression'

previous_model_weights_to_load = "" # If non-empty, load weights from a previous model (note: architectures must be identical)
model_architecture = 'CNN' # 'FCN', 'CNN'
data_input_table_structure = 'Raw_Timeseries' # 'Vectorized_By_Row' 'Raw_Timeseries'
if machine_to_run_script == 'local':
    folder_head_loc = '../';
    folder_data_loc = 'C:/Users/adam/Documents/Lumo/Lumo Data/'
elif machine_to_run_script == 'Sherlock':
    folder_head_loc = '/home/users/agotlin/lumo/'
    folder_data_loc = '/home/users/agotlin/SherlockDataFiles/'
myFileName = 'TimeSeries_InputRaw_1000Runs_QuarterSample'
myFileLocation = folder_data_loc + myFileName + '.csv'
    # Other data files/folders to potentially use:
    # 'TimeSeries_InputVector_100runs'   |   'TimeSeries_InputVector_15runs'
    # 'TimeSeries_InputRaw_1000Runs'  |  'TimeSeries_InputRaw_1000Runs_QuarterSample'  |  'TimeSeries_InputRaw_1000Runs_Top10kRowsSample'
    
# Training strategy
batch_size_all = [64, 128] # we used 50 for CNN, 128 for FCN
learning_rate_all = [0.0001] # we used 0.001 for FCN, 0.0001 for CNN
optimizer_type_all = ['gradient'] # options are: "adam" , "rmsprop", "gradient" # adam for FCN, gradient for CNN
loss_function_all = ['mae'] # Other options (from keras defaults or custom) include: 'categorical_crossentropy' ,'mse', 'mae', 'class_mse', 'class_mae'    
training_epochs_all = [100]
    
# Fully Connected Architecture

num_hidden_units_fc_layers = [256, 256, 256, 128, 128, 128]
hidden_units_strategy = ''.join(str(num) + "_" for num in num_hidden_units_fc_layers) # document strategy 
num_hidden_fc_layers = len(num_hidden_units_fc_layers) # document strategy
activations_fc_layers = ['relu', 'relu', 'relu', 'relu', 'relu', 'relu']
activations_strategy = ''.join(str(num) + "_" for num in activations_fc_layers) # document strategy
dropout_rate_fc_layers = [1.0, 1.0, 1.0, 0.8, 0.8, 0.8]
dropout_rates = ''.join(str(num) + "_" for num in dropout_rate_fc_layers) # document strategy

# Convolutional Architecture
    
sample_stride = input_window_size/2 # how many timestamps to shift over between each unique training example # 18, input_window_size/2
num_filters = 40 # number of filters in Conv2D layer (aka depth) # we used 40, ex; used 128
kernel_size = 5 # kernal size of the Conv2D layer # we use 6, example used 2, I would guess closer to 3
activation_conv_layer = "relu" # options are "relu" , "tanh" and "sigmoid" - used for depthwise_conv
max_pool_kernel_size = 5 # max pooling window size# we use 6, example used 2, I don't agre with 6
conv_layer_dropout = 0.2 # dropout ratio for dropout layer # we don't use in our model

num_hidden_units_fc_layers_CNN = [50]
hidden_units_strategy_CNN = ''.join(str(num) + "_" for num in num_hidden_units_fc_layers_CNN) # document strategy 
num_hidden_fc_layers_CNN = len(num_hidden_units_fc_layers_CNN) # document strategy
activations_fc_layers_CNN = ['tanh']
activations_strategy_CNN = ''.join(str(num) + "_" for num in activations_fc_layers_CNN) # document strategy
dropout_rate_fc_layers_CNN = [1.0]
dropout_rates_CNN = ''.join(str(num) + "_" for num in dropout_rate_fc_layers_CNN) # document strategy

# %% [markdown]
# #### Set Up Automatic Reporting and Plotting

# %%
# Choose the 3 most interesting evaluation metrics to report on in final plots
if speed_bucket_size != 'none_use_regression': 
    accuracy_reporting_metric_1 = 'class_mae' # options: 'acc', 'class_percent_1buckRange', 'class_percent_2buckRange'
    dev_reporting_metric_1 = 'val_' + accuracy_reporting_metric_1
    accuracy_reporting_metric_2 = 'class_mse' # options: 'acc', 'class_percent_1buckRange', 'class_percent_2buckRange'
    dev_reporting_metric_2 = 'val_' + accuracy_reporting_metric_2
    accuracy_reporting_metric_3 = 'class_percent_2buckRange' # options: s'acc', 'class_percent_1buckRange', 'class_percent_2buckRange'
    dev_reporting_metric_3 = 'val_' + accuracy_reporting_metric_3    
    accuracy_reporting_metric_4 = 'acc' # options: s'acc', 'class_percent_1buckRange', 'class_percent_2buckRange'
    dev_reporting_metric_4 = 'val_' + accuracy_reporting_metric_4
else:
    accuracy_reporting_metric_1 = 'mean_absolute_error' # options: 'acc', 'class_percent_1buckRange', 'class_percent_2buckRange'
    dev_reporting_metric_1 = 'val_' + accuracy_reporting_metric_1
    accuracy_reporting_metric_2 = 'mean_squared_error' # options: 'acc', 'class_percent_1buckRange', 'class_percent_2buckRange'
    dev_reporting_metric_2 = 'val_' + accuracy_reporting_metric_2
    accuracy_reporting_metric_3 = 'loss' # options: s'acc', 'class_percent_1buckRange', 'class_percent_2buckRange'
    dev_reporting_metric_3 = 'val_' + accuracy_reporting_metric_3
    accuracy_reporting_metric_4 = 'loss' # options: s'acc', 'class_percent_1buckRange', 'class_percent_2buckRange' # A bandaid since the results reporting script requires 4 metrics
    dev_reporting_metric_4 = 'val_' + accuracy_reporting_metric_4    

# File naming conventions
plot_note = ""
results_file_name = "Default_Model_Results_Table_20180911" + "_" + model_architecture

# Style of matlab plots to produce
plt.style.use('ggplot')

# %% [markdown]
# #### Define functions for data processing and plotting

# %%
from SpeedPrediction_Helper import *

# %% [markdown]
# #### Normalize Data

# %%
dataset = read_data(myFileLocation)

if data_input_table_structure == 'Raw_Timeseries':
    dataset_inputs = dataset.loc[:, 'gender':'pelvic_rotation'] # normalize all columns from gender to pelvic_tilt
    dataset_inputs_normalized = (dataset_inputs - dataset_inputs.mean())/dataset_inputs.std()
elif data_input_table_structure == 'Vectorized_By_Row':
    dataset_inputs = dataset.loc[:, 'gender':'pelvic_rotation_lag_0'] # normalize all columns from gender to pelvic_rotation_lag_0
    dataset_inputs_normalized = (dataset_inputs - dataset_inputs.mean())/dataset_inputs.std()

# %%
print('Successfuly normalized data!')
# Out:
# Successfuly normalized data!

# %% [markdown]
# #### Preprocess data to input into model

# %%
np_array_file_string_segment = folder_data_loc + "SavedNPArrays/" + str(myFileName) + "_" + model_architecture + "_" + str(input_window_size) + "_" + str(label_window_size) + "_" + str(sample_stride) + "_segment.npy"
np_array_file_string_segment_timeseries = folder_data_loc + "SavedNPArrays/" + str(myFileName) + "_" + model_architecture + "_" + str(input_window_size) + "_" + str(label_window_size) + "_" + str(sample_stride) + "_segment_timeseries.npy"
np_array_file_string_segment_anthro = folder_data_loc + "SavedNPArrays/" + str(myFileName) + "_" + model_architecture + "_" + str(input_window_size) + "_" + str(label_window_size) + "_" + str(sample_stride) + "_segment_anthro.npy"
np_array_file_string_label = folder_data_loc + "SavedNPArrays/" + str(myFileName) + "_" + model_architecture + "_" +  str(input_window_size) + "_" + str(label_window_size) + "_" + str(sample_stride) + "_label.npy"
np_array_file_string_label2num = folder_data_loc + "SavedNPArrays/" + str(myFileName) + "_" + model_architecture + "_" + str(input_window_size) + "_" + str(label_window_size) + "_" + str(sample_stride) + "_label2num.npy"

if speed_bucket_size == 'none_use_regression': # A bandaid script since regression and classification were not differentiated in above naming convention
    np_array_file_string_segment = folder_data_loc + "SavedNPArrays/" + str(myFileName) + "_" + model_architecture + "_" + str(input_window_size) + "_" + str(label_window_size) + "_" + str(sample_stride) + "_segment_regr.npy"
    np_array_file_string_segment_timeseries = folder_data_loc + "SavedNPArrays/" + str(myFileName) + "_" + model_architecture + "_" + str(input_window_size) + "_" + str(label_window_size) + "_" + str(sample_stride) + "_segment_timeseries_regr.npy"
    np_array_file_string_segment_anthro = folder_data_loc + "SavedNPArrays/" + str(myFileName) + "_" + model_architecture + "_" + str(input_window_size) + "_" + str(label_window_size) + "_" + str(sample_stride) + "_segment_anthro_regr.npy"
    np_array_file_string_label = folder_data_loc + "SavedNPArrays/" + str(myFileName) + "_" + model_architecture + "_" +  str(input_window_size) + "_" + str(label_window_size) + "_" + str(sample_stride) + "_label_regr.npy"
    
if os.path.isfile(np_array_file_string_label):   # if this file already exists, load the relevant SavedNPArrays
    print('Pulling down ' + np_array_file_string_label)
    if  model_architecture == 'FCN':
        segments = np.load(np_array_file_string_segment, allow_pickle=True)
    elif model_architecture == 'CNN':
        segments_timeseries = np.load(np_array_file_string_segment_timeseries, allow_pickle=True)
        segments_anthro = np.load(np_array_file_string_segment_anthro, allow_pickle=True)
    labels = np.load(np_array_file_string_label, allow_pickle=True)
    labels_to_number = np.load(np_array_file_string_label2num, allow_pickle=True)
else:    # if this file does not exist, run segment_signal method and create np arrays for future use
    print('Creating ' + np_array_file_string_label)
    if data_input_table_structure == 'Raw_Timeseries':
        if  model_architecture == 'FCN':
            segments, labels = segment_signal_w_concat(dataset_inputs_normalized, dataset, model_architecture, speed_bucket_size, input_window_size, num_channels, num_anthropometrics, label_window_size, sample_stride)
        elif model_architecture == 'CNN':
            segments_timeseries, segments_anthro, labels = segment_signal_w_concat(dataset_inputs_normalized, dataset, model_architecture, speed_bucket_size, input_window_size, num_channels, num_anthropometrics,label_window_size, sample_stride)
    elif data_input_table_structure == 'Vectorized_By_Row':
        segments, labels = segment_signal_FCN_vector(dataset_inputs_normalized, dataset)
    if speed_bucket_size != 'none_use_regression': # if not using regression, convert to one-hot vector labels
        labels_to_number = np.unique(labels) # Caches "labels_to_number" in order to use in rmse calculation for classification
        labels = np.asarray(pd.get_dummies(labels), dtype = np.int8) # one-hot labels to classify nearest bucket
        np.save(np_array_file_string_label2num, labels_to_number, allow_pickle=True)
    else:
        labels_to_number = [0] # A bandaid placeholder to report labels_to_number in confusion matrix script
    if  model_architecture == 'FCN':
        np.save(np_array_file_string_segment, segments, allow_pickle=True)
    elif model_architecture == 'CNN':
        np.save(np_array_file_string_segment_timeseries, segments_timeseries, allow_pickle=True)
        np.save(np_array_file_string_segment_anthro, segments_anthro, allow_pickle=True)
    np.save(np_array_file_string_label, labels, allow_pickle=True)

if speed_bucket_size != 'none_use_regression':
    num_buckets_total = len(labels[1]) # total number of classification buckets that exist in the dataset (here, classification bucket == classification class)
# Out:
# Pulling down C:/Users/adam/Documents/Lumo/Lumo Data/SavedNPArrays/TimeSeries_InputRaw_1000Runs_QuarterSample_CNN_26_20_13.0_label_regr.npy

# %%
print('Successfully preprocessed data!')
# Out:
# Successfully preprocessed data!

# %% [markdown]
# #### Shuffle data into training and dev

# %%
train_dev_split = np.random.rand(len(labels)) < 0.90 # split data into 90% train, 10% dev, based on lenghto of labels

if  model_architecture == 'FCN':
    X_train = segments[train_dev_split]
    X_test = segments[~train_dev_split]
elif model_architecture == 'CNN':
    X_train_timeseries = segments_timeseries[train_dev_split]
    X_test_timeseries = segments_timeseries[~train_dev_split]
    X_train_anthro = segments_anthro[train_dev_split]
    X_test_anthro = segments_anthro[~train_dev_split]

y_train = labels[train_dev_split]
y_test = labels[~train_dev_split]

# %% [markdown]
# #### Implement NN architecture in a Keras model

# %%
def fcnModel():
    model = Sequential()
    # First layer
    model.add(Dense(num_hidden_units_fc_layers[0], activation=activations_fc_layers[0], input_shape=(input_window_size*num_channels + num_anthropometrics,)))
    model.add(BatchNormalization())
    model.add(Dropout(dropout_rate_fc_layers[0]))
    # Intermediate layers
    for L in range(1, num_hidden_fc_layers):
        model.add(Dense(num_hidden_units_fc_layers[L], activation=activations_fc_layers[L]))
        model.add(BatchNormalization())
        model.add(Dropout(dropout_rate_fc_layers[L]))
    # Last hidden layer
    if speed_bucket_size != 'none_use_regression': # if classification, use softmax for last layer
        model.add(Dense(num_buckets_total, activation='softmax'))
    else:                                          # if regression, use linear for last layer
        model.add(Dense(1,activation='linear'))
        
    model.compile(loss = loss_function, optimizer=model_optimizer, metrics=['mse','mae']) # options: 'mse','mae', 'mape'
        
        
    return model

def cnnModel_multInput(): # (inputs, outputs):
    # CNN over time-series data
    input_cnn = Input(shape=(input_window_size, num_channels))
    conv1 = Conv1D(num_filters, kernel_size,activation=activation_conv_layer)(input_cnn)
    pool1 = MaxPooling1D(pool_size=max_pool_kernel_size, padding='valid', strides=(2))(conv1)
    conv2 = Conv1D(num_filters//10, kernel_size, activation=activation_conv_layer)(pool1) # add additional CNN layer
    flat1 = Flatten()(conv2)
    # Include anthropometric data
    input_anthro = Input(shape=(num_anthropometrics,))
    # Concatenate result of CNN with antropometric data
    merged = concatenate([flat1, input_anthro])
    # Add fully connected hident layers after concatenating (at least one)
    fc1 = Dense(num_hidden_units_fc_layers_CNN[0], activation=activations_fc_layers_CNN[0])(merged) # add first fully connected layer
    for L in range(1, num_hidden_fc_layers_CNN):
        None
        # NEED TO CORRECT BEFORE USE    
        #something like this
        #fc_L = Dense(num_hidden_units_fc_layers_CNN[L], activation=activations_fc_layers_CNN[L])(fc_L-1) # add first fully connected layer
        #model.add(BatchNormalization())
        #model.add(Dropout(dropout_rate_fc_layers_CNN[L]))
    if speed_bucket_size != 'none_use_regression': # if classification, use softmax for last layer
        output = Dense(num_buckets_total, activation='softmax')(fc1) # will need to change with more fc layers
        
        #Test Code for Dot Product
        #sofma = Dense(num_buckets_total, activation='softmax')(fc1) # will need to change with more fc layers
        #output = Lambda(lambda sofma: sofma*labels_to_number)
        #output = Merge([sofma, labels_to_number], mode='dot', dot_axes=(1, 1))
        
    else:                                          # if regression, use linear for last layer
        output = Dense(1,activation='linear')(fc1)  
    model = Model(inputs = [input_cnn, input_anthro], outputs = output)
    return model

# %%
if  model_architecture == 'FCN':
    model = fcnModel()
elif model_architecture == 'CNN':
    model = cnnModel_multInput()

# %%
# View model summary
model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_7 (InputLayer)            (None, 26, 6)        0
# __________________________________________________________________________________________________
# conv1d_7 (Conv1D)               (None, 22, 40)       1240        input_7[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_4 (MaxPooling1D)  (None, 9, 40)        0           conv1d_7[0][0]
# __________________________________________________________________________________________________
# conv1d_8 (Conv1D)               (None, 5, 4)         804         max_pooling1d_4[0][0]
# __________________________________________________________________________________________________
# flatten_4 (Flatten)             (None, 20)           0           conv1d_8[0][0]
# __________________________________________________________________________________________________
# input_8 (InputLayer)            (None, 4)            0
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 24)           0           flatten_4[0][0]
#                                                                  input_8[0][0]
# __________________________________________________________________________________________________
# dense_6 (Dense)                 (None, 50)           1250        concatenate_4[0][0]
# __________________________________________________________________________________________________
# dense_7 (Dense)                 (None, 1)            51          dense_6[0][0]
# ==================================================================================================
# Total params: 3,345
# Trainable params: 3,345
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# #### Define custom loss functions and evaluation metrics

# %%
# Custom loss functions

def class_mse(y_true, y_pred):
    return K.mean(K.square(K.sum(y_pred * labels_to_number,axis=-1,keepdims=True) - K.sum(y_true * labels_to_number,axis=-1,keepdims=True)), axis=-1)
    # Note: we cannot define RMSE directly in Keras since the loss function is defined for one training example at a time

def class_mae(y_true, y_pred):
    return K.mean(K.abs(K.sum(y_pred * labels_to_number,axis=-1,keepdims=True) - K.sum(y_true * labels_to_number,axis=-1,keepdims=True)), axis=-1)

def class_mape(y_true, y_pred):
    diff = K.abs((K.sum(y_true * labels_to_number,axis=-1,keepdims=True) - K.sum(y_pred * labels_to_number,axis=-1,keepdims=True)) / K.clip(K.abs(K.sum(y_true * labels_to_number,axis=-1,keepdims=True)),K.epsilon(),None))
    return 100. * K.mean(diff, axis=-1)

def class_percent_2buckLow(y_true, y_pred): # percent of times the prediction is 2 buckets below the true value
    return K.cast(K.equal(K.cast(K.argmax(y_true, axis=-1), K.floatx()), K.cast(K.argmax(y_pred, axis=-1),K.floatx())+2.0), K.floatx())

def class_percent_2buckHigh(y_true, y_pred): # percent of times the prediction is 2 buckets above the true value
    return K.cast(K.equal(K.cast(K.argmax(y_true, axis=-1), K.floatx()), K.cast(K.argmax(y_pred, axis=-1),K.floatx())-2.0), K.floatx())    

def class_percent_2buckRange(y_true, y_pred): # percent of times the prediction is within 2 buckets of true value
    return K.cast(K.equal(K.argmax(y_true, axis=-1),K.argmax(y_pred, axis=-1)),K.floatx()) + \
    K.cast(K.equal(K.cast(K.argmax(y_true, axis=-1), K.floatx()), K.cast(K.argmax(y_pred, axis=-1),K.floatx())-1.0), K.floatx()) + \
    K.cast(K.equal(K.cast(K.argmax(y_true, axis=-1), K.floatx()), K.cast(K.argmax(y_pred, axis=-1),K.floatx())+1.0), K.floatx()) + \
    K.cast(K.equal(K.cast(K.argmax(y_true, axis=-1), K.floatx()), K.cast(K.argmax(y_pred, axis=-1),K.floatx())-2.0), K.floatx()) + \
    K.cast(K.equal(K.cast(K.argmax(y_true, axis=-1), K.floatx()), K.cast(K.argmax(y_pred, axis=-1),K.floatx())+2.0), K.floatx())

# %% [markdown]
# #### Configure training run ... model loss and optimization function

# %%
# Show progress if running on local, only show final epoch values when running on Sherlock, don't show anything in a loop
if (machine_to_run_script == 'local') & (runs_per_file == 'single'):
    verbose_option = 1 # show progress bar
elif (machine_to_run_script == 'Sherlock') & (runs_per_file == 'single'):
    verbose_option = 2 # one line per epoch # 0 stay silent
elif (machine_to_run_script == 'local') & (runs_per_file == 'train_loop'):
    verbose_option = 2 # one line per epoch # 0 stay silent
elif (machine_to_run_script == 'Sherlock') & (runs_per_file == 'train_loop'):
    verbose_option = 0 # silent

# %% [markdown]
# #### Train!

# %%
for batch_size,learning_rate,optimizer_type,loss_function,training_epochs in itertools.product(batch_size_all,learning_rate_all,optimizer_type_all,loss_function_all,training_epochs_all):
    
    # Model run file naming conventions
    file_name = strftime("%Y%m%d_%H%M%S", gmtime()) # user input for filename of saved model
    print('Starting to train model ' + file_name + ': bs='+str(batch_size)+', lr='+str(learning_rate)+', opt='+optimizer_type+', lf='+loss_function+', epochs='+str(training_epochs))
    
    # If desired, load weights from a previous model to start with model
    if previous_model_weights_to_load != "":
        model.load_weights(folder_head_loc + "Model Final Parameters/" + previous_model_weights_to_load)
    
    # Define optimizer
    if optimizer_type == 'adam':
        model_optimizer = optimizers.Adam(lr = learning_rate) #, decay, beta_1, beta_2 are HPs
    elif optimizer_type == 'rmsprop':
        model_optimizer = optimizers.RMSprop(lr = learning_rate) #, decay, rho
    elif optimizer_type == 'gradient':
        model_optimizer = optimizers.SGD(lr = learning_rate) #, decay, momentum
    
    # Compile model with appropriate loss function
    if speed_bucket_size != 'none_use_regression': # if performing classification, ALWAYS use cross-entropy loss
        model.compile(loss ='categorical_crossentropy', optimizer=model_optimizer, metrics=['accuracy',class_percent_2buckRange, class_mae, class_mse]) # class_percent_1buckLow,class_percent_1buckHigh,class_percent_2buckLow, class_percent_2buckHigh,'class_mape'
    else:                                          # if performing regression, use mean squared error or mean absolute error
        if loss_function == 'categorical_crossentropy': raise NameError('Are you sure you want to use cross entropy loss with a regression tasks!?')
        model.compile(loss = loss_function, optimizer=model_optimizer, metrics=['mse','mae']) # options: 'mse','mae', 'mape'

    # Train model
    start_time = time.time()
    if  model_architecture == 'FCN':
        history = model.fit(X_train, y_train, batch_size= batch_size, epochs=training_epochs, verbose=verbose_option, validation_data=(X_test, y_test))
    elif model_architecture == 'CNN':
        history = model.fit([X_train_timeseries, X_train_anthro], y_train, batch_size= batch_size, epochs=training_epochs, verbose=verbose_option, validation_data=([X_test_timeseries, X_test_anthro], y_test))
    end_time=time.time()
    
    print('Finished training model ' + file_name + '!')
        
    # Transform key results into a np arrary
    trainAccuracy_1 = np.squeeze(history.history[accuracy_reporting_metric_1])
    devAccuracy_1 = np.squeeze(history.history[dev_reporting_metric_1])
    trainAccuracy_2 = np.squeeze(history.history[accuracy_reporting_metric_2])
    devAccuracy_2 = np.squeeze(history.history[dev_reporting_metric_2])    
    trainAccuracy_3 = np.squeeze(history.history[accuracy_reporting_metric_3])
    devAccuracy_3 = np.squeeze(history.history[dev_reporting_metric_3])
    trainAccuracy_4 = np.squeeze(history.history[accuracy_reporting_metric_4])
    devAccuracy_4 = np.squeeze(history.history[dev_reporting_metric_4])
    epochs = np.squeeze(range(1,training_epochs + 1))
    # Declare final values for results
    final_accuracy_1 = history.history[accuracy_reporting_metric_1][training_epochs - 1]
    final_accuracy_dev_1 = history.history[dev_reporting_metric_1][training_epochs - 1]
    final_accuracy_2 = history.history[accuracy_reporting_metric_2][training_epochs - 1]
    final_accuracy_dev_2 = history.history[dev_reporting_metric_2][training_epochs - 1]
    final_accuracy_3 = history.history[accuracy_reporting_metric_3][training_epochs - 1]
    final_accuracy_dev_3 = history.history[dev_reporting_metric_3][training_epochs - 1]
    final_accuracy_4 = history.history[accuracy_reporting_metric_4][training_epochs - 1]
    final_accuracy_dev_4 = history.history[dev_reporting_metric_4][training_epochs - 1]
    # Save results to a .csv in the "Learning Curve Results"
    df_devAccuracy = pd.DataFrame(np.transpose(np.vstack([epochs,devAccuracy_1, devAccuracy_2, devAccuracy_3, devAccuracy_4])))
    filepath_acc = folder_head_loc + "Learning Curves/" + str(file_name) +"_AccuracyPerEpoch_Data" + ".csv"
    df_devAccuracy.to_csv(filepath_acc, header = ["Epochs", dev_reporting_metric_1, dev_reporting_metric_2, dev_reporting_metric_3, 'acc'], index=False)

    # Create a plot of Learning Curves
    create_learning_curves_from_model(machine_to_run_script
                ,trainAccuracy_4
                ,devAccuracy_4
                ,trainAccuracy_1
                ,devAccuracy_1
                ,trainAccuracy_2
                ,devAccuracy_2
                ,dev_reporting_metric_1
                ,final_accuracy_dev_1
                ,dev_reporting_metric_2
                ,final_accuracy_dev_2
                ,loss_function
                ,learning_rate
                ,batch_size
                ,speed_bucket_size
                ,training_epochs
                ,input_window_size
                ,labels_to_number
                ,accuracy_reporting_metric_1
                ,accuracy_reporting_metric_2
                ,accuracy_reporting_metric_3
                ,plot_note
                ,folder_head_loc
                ,file_name)

    # Add the results of the most recent run to the results file for documentation
    populate_results_performance_table(folder_head_loc,
                results_file_name,
                model_architecture,
                file_name,
                myFileLocation,
                training_epochs,  
                end_time,
                start_time,
                final_accuracy_1,
                final_accuracy_dev_1,
                final_accuracy_2,
                final_accuracy_dev_2,
                final_accuracy_3,
                final_accuracy_dev_3,
                batch_size,    
                learning_rate,
                speed_bucket_size,
                loss_function,
                input_window_size,
                label_window_size,
                optimizer_type,
                accuracy_reporting_metric_1,
                accuracy_reporting_metric_2,
                accuracy_reporting_metric_3,
                num_hidden_fc_layers,
                hidden_units_strategy,
                activations_strategy,
                dropout_rates,
                hidden_units_strategy_CNN,
                num_filters,
                kernel_size,
                sample_stride,
                activation_conv_layer,
                activations_strategy_CNN,
                max_pool_kernel_size)    
        
    # Create confusion matrices
    if speed_bucket_size != 'none_use_regression': 
        if  model_architecture == 'FCN':
                y_pred = model.predict(X_test)
        elif model_architecture == 'CNN':
            y_pred = model.predict([X_test_timeseries, X_test_anthro])
        y_pred_argmax = np.argmax(y_pred, axis=1)
        y_true = y_test
        y_true_argmax = np.argmax(y_true, axis=1)  
        create_conf_matrix_from_model(machine_to_run_script
                ,y_true_argmax
                ,y_pred_argmax
                ,folder_head_loc
                ,file_name)
    
    print('Successfully created plots and figures for model ' + file_name)
    
    # Save model weights
    if machine_to_run_script == 'local':
        completed_model_name = file_name + "_" + model_architecture
        model.save_weights(folder_head_loc + "Model Final Parameters/" + completed_model_name + '_weights.h5')
        # THIS DOES NOT WORK IN SHERLOCK RIGHT NOW
        
print('Completed all training runs!')
# Out:
# Starting to train model 20180917_191016: bs=64, lr=0.0001, opt=gradient, lf=mae, epochs=100
# Train on 17036 samples, validate on 1909 samples
# Epoch 1/100
#  - 3s - loss: 2.5979 - mean_squared_error: 7.2599 - mean_absolute_error: 2.5979 - val_loss: 2.4656 - val_mean_squared_error: 6.6046 - val_mean_absolute_error: 2.4656
# Epoch 2/100
#  - 2s - loss: 2.3911 - mean_squared_error: 6.2558 - mean_absolute_error: 2.3911 - val_loss: 2.2509 - val_mean_squared_error: 5.6183 - val_mean_absolute_error: 2.2509
# Epoch 3/100
#  - 2s - loss: 2.1473 - mean_squared_error: 5.1871 - mean_absolute_error: 2.1473 - val_loss: 1.9754 - val_mean_squared_error: 4.4894 - val_mean_absolute_error: 1.9754
# Epoch 4/100
#  - 2s - loss: 1.8123 - mean_squared_error: 3.9038 - mean_absolute_error: 1.8123 - val_loss: 1.5875 - val_mean_squared_error: 3.1137 - val_mean_absolute_error: 1.5875
# Epoch 5/100
#  - 2s - loss: 1.3745 - mean_squared_error: 2.4684 - mean_absolute_error: 1.3745 - val_loss: 1.1362 - val_mean_squared_error: 1.7833 - val_mean_absolute_error: 1.1362
# Epoch 6/100
#  - 2s - loss: 0.9625 - mean_squared_error: 1.3597 - mean_absolute_error: 0.9625 - val_loss: 0.8119 - val_mean_squared_error: 1.0066 - val_mean_absolute_error: 0.8119
# Epoch 7/100
#  - 2s - loss: 0.7280 - mean_squared_error: 0.8373 - mean_absolute_error: 0.7280 - val_loss: 0.6630 - val_mean_squared_error: 0.7149 - val_mean_absolute_error: 0.6630
# Epoch 8/100
#  - 2s - loss: 0.6232 - mean_squared_error: 0.6409 - mean_absolute_error: 0.6232 - val_loss: 0.5906 - val_mean_squared_error: 0.5959 - val_mean_absolute_error: 0.5906
# Epoch 9/100
#  - 2s - loss: 0.5641 - mean_squared_error: 0.5498 - mean_absolute_error: 0.5641 - val_loss: 0.5441 - val_mean_squared_error: 0.5282 - val_mean_absolute_error: 0.5441
# Epoch 10/100
#  - 2s - loss: 0.5236 - mean_squared_error: 0.4933 - mean_absolute_error: 0.5236 - val_loss: 0.5099 - val_mean_squared_error: 0.4822 - val_mean_absolute_error: 0.5099
# Epoch 11/100
#  - 2s - loss: 0.4932 - mean_squared_error: 0.4538 - mean_absolute_error: 0.4932 - val_loss: 0.4835 - val_mean_squared_error: 0.4486 - val_mean_absolute_error: 0.4835
# Epoch 12/100
#  - 2s - loss: 0.4698 - mean_squared_error: 0.4250 - mean_absolute_error: 0.4698 - val_loss: 0.4629 - val_mean_squared_error: 0.4240 - val_mean_absolute_error: 0.4629
# Epoch 13/100
#  - 2s - loss: 0.4517 - mean_squared_error: 0.4036 - mean_absolute_error: 0.4517 - val_loss: 0.4468 - val_mean_squared_error: 0.4054 - val_mean_absolute_error: 0.4468
# Epoch 14/100
#  - 2s - loss: 0.4374 - mean_squared_error: 0.3873 - mean_absolute_error: 0.4374 - val_loss: 0.4335 - val_mean_squared_error: 0.3903 - val_mean_absolute_error: 0.4335
# Epoch 15/100
#  - 2s - loss: 0.4260 - mean_squared_error: 0.3741 - mean_absolute_error: 0.4260 - val_loss: 0.4231 - val_mean_squared_error: 0.3791 - val_mean_absolute_error: 0.4231
# Epoch 16/100
#  - 2s - loss: 0.4166 - mean_squared_error: 0.3643 - mean_absolute_error: 0.4166 - val_loss: 0.4144 - val_mean_squared_error: 0.3692 - val_mean_absolute_error: 0.4144
# Epoch 17/100
#  - 2s - loss: 0.4088 - mean_squared_error: 0.3557 - mean_absolute_error: 0.4088 - val_loss: 0.4072 - val_mean_squared_error: 0.3610 - val_mean_absolute_error: 0.4072
# Epoch 18/100
#  - 2s - loss: 0.4021 - mean_squared_error: 0.3483 - mean_absolute_error: 0.4021 - val_loss: 0.4010 - val_mean_squared_error: 0.3553 - val_mean_absolute_error: 0.4010
# Epoch 19/100
#  - 2s - loss: 0.3965 - mean_squared_error: 0.3427 - mean_absolute_error: 0.3965 - val_loss: 0.3957 - val_mean_squared_error: 0.3494 - val_mean_absolute_error: 0.3957
# Epoch 20/100
#  - 2s - loss: 0.3916 - mean_squared_error: 0.3372 - mean_absolute_error: 0.3916 - val_loss: 0.3913 - val_mean_squared_error: 0.3458 - val_mean_absolute_error: 0.3913
# Epoch 21/100
#  - 2s - loss: 0.3874 - mean_squared_error: 0.3331 - mean_absolute_error: 0.3874 - val_loss: 0.3875 - val_mean_squared_error: 0.3417 - val_mean_absolute_error: 0.3875
# Epoch 22/100
#  - 2s - loss: 0.3837 - mean_squared_error: 0.3295 - mean_absolute_error: 0.3837 - val_loss: 0.3841 - val_mean_squared_error: 0.3375 - val_mean_absolute_error: 0.3841
# Epoch 23/100
#  - 2s - loss: 0.3804 - mean_squared_error: 0.3259 - mean_absolute_error: 0.3804 - val_loss: 0.3811 - val_mean_squared_error: 0.3342 - val_mean_absolute_error: 0.3811
# Epoch 24/100
#  - 2s - loss: 0.3775 - mean_squared_error: 0.3227 - mean_absolute_error: 0.3775 - val_loss: 0.3784 - val_mean_squared_error: 0.3316 - val_mean_absolute_error: 0.3784
# Epoch 25/100
#  - 2s - loss: 0.3748 - mean_squared_error: 0.3200 - mean_absolute_error: 0.3748 - val_loss: 0.3760 - val_mean_squared_error: 0.3295 - val_mean_absolute_error: 0.3760
# Epoch 26/100
#  - 2s - loss: 0.3723 - mean_squared_error: 0.3176 - mean_absolute_error: 0.3723 - val_loss: 0.3737 - val_mean_squared_error: 0.3273 - val_mean_absolute_error: 0.3737
# Epoch 27/100
#  - 2s - loss: 0.3700 - mean_squared_error: 0.3153 - mean_absolute_error: 0.3700 - val_loss: 0.3716 - val_mean_squared_error: 0.3251 - val_mean_absolute_error: 0.3716
# Epoch 28/100
#  - 2s - loss: 0.3680 - mean_squared_error: 0.3134 - mean_absolute_error: 0.3680 - val_loss: 0.3696 - val_mean_squared_error: 0.3224 - val_mean_absolute_error: 0.3696
# Epoch 29/100
#  - 2s - loss: 0.3661 - mean_squared_error: 0.3114 - mean_absolute_error: 0.3661 - val_loss: 0.3679 - val_mean_squared_error: 0.3209 - val_mean_absolute_error: 0.3679
# Epoch 30/100
#  - 2s - loss: 0.3644 - mean_squared_error: 0.3099 - mean_absolute_error: 0.3644 - val_loss: 0.3663 - val_mean_squared_error: 0.3189 - val_mean_absolute_error: 0.3663
# Epoch 31/100
#  - 3s - loss: 0.3627 - mean_squared_error: 0.3080 - mean_absolute_error: 0.3627 - val_loss: 0.3648 - val_mean_squared_error: 0.3177 - val_mean_absolute_error: 0.3648
# Epoch 32/100
#  - 2s - loss: 0.3612 - mean_squared_error: 0.3064 - mean_absolute_error: 0.3612 - val_loss: 0.3634 - val_mean_squared_error: 0.3165 - val_mean_absolute_error: 0.3634
# Epoch 33/100
#  - 2s - loss: 0.3597 - mean_squared_error: 0.3051 - mean_absolute_error: 0.3597 - val_loss: 0.3620 - val_mean_squared_error: 0.3149 - val_mean_absolute_error: 0.3620
# Epoch 34/100
#  - 2s - loss: 0.3583 - mean_squared_error: 0.3035 - mean_absolute_error: 0.3583 - val_loss: 0.3607 - val_mean_squared_error: 0.3135 - val_mean_absolute_error: 0.3607
# Epoch 35/100
#  - 2s - loss: 0.3570 - mean_squared_error: 0.3023 - mean_absolute_error: 0.3570 - val_loss: 0.3593 - val_mean_squared_error: 0.3119 - val_mean_absolute_error: 0.3593
# Epoch 36/100
#  - 2s - loss: 0.3558 - mean_squared_error: 0.3010 - mean_absolute_error: 0.3558 - val_loss: 0.3580 - val_mean_squared_error: 0.3100 - val_mean_absolute_error: 0.3580
# Epoch 37/100
#  - 2s - loss: 0.3546 - mean_squared_error: 0.2995 - mean_absolute_error: 0.3546 - val_loss: 0.3568 - val_mean_squared_error: 0.3089 - val_mean_absolute_error: 0.3568
# Epoch 38/100
#  - 2s - loss: 0.3535 - mean_squared_error: 0.2982 - mean_absolute_error: 0.3535 - val_loss: 0.3558 - val_mean_squared_error: 0.3086 - val_mean_absolute_error: 0.3558
# Epoch 39/100
#  - 2s - loss: 0.3524 - mean_squared_error: 0.2974 - mean_absolute_error: 0.3524 - val_loss: 0.3547 - val_mean_squared_error: 0.3074 - val_mean_absolute_error: 0.3547
# Epoch 40/100
#  - 2s - loss: 0.3513 - mean_squared_error: 0.2965 - mean_absolute_error: 0.3513 - val_loss: 0.3535 - val_mean_squared_error: 0.3057 - val_mean_absolute_error: 0.3535
# Epoch 41/100
#  - 2s - loss: 0.3503 - mean_squared_error: 0.2950 - mean_absolute_error: 0.3503 - val_loss: 0.3526 - val_mean_squared_error: 0.3056 - val_mean_absolute_error: 0.3526
# Epoch 42/100
#  - 2s - loss: 0.3493 - mean_squared_error: 0.2945 - mean_absolute_error: 0.3493 - val_loss: 0.3515 - val_mean_squared_error: 0.3042 - val_mean_absolute_error: 0.3515
# Epoch 43/100
#  - 2s - loss: 0.3483 - mean_squared_error: 0.2934 - mean_absolute_error: 0.3483 - val_loss: 0.3504 - val_mean_squared_error: 0.3026 - val_mean_absolute_error: 0.3504
# Epoch 44/100
#  - 2s - loss: 0.3474 - mean_squared_error: 0.2922 - mean_absolute_error: 0.3474 - val_loss: 0.3496 - val_mean_squared_error: 0.3021 - val_mean_absolute_error: 0.3496
# Epoch 45/100
#  - 2s - loss: 0.3464 - mean_squared_error: 0.2912 - mean_absolute_error: 0.3464 - val_loss: 0.3487 - val_mean_squared_error: 0.3016 - val_mean_absolute_error: 0.3487
# Epoch 46/100
#  - 2s - loss: 0.3455 - mean_squared_error: 0.2903 - mean_absolute_error: 0.3455 - val_loss: 0.3478 - val_mean_squared_error: 0.3009 - val_mean_absolute_error: 0.3478
# Epoch 47/100
#  - 2s - loss: 0.3445 - mean_squared_error: 0.2896 - mean_absolute_error: 0.3445 - val_loss: 0.3466 - val_mean_squared_error: 0.2990 - val_mean_absolute_error: 0.3466
# Epoch 48/100
#  - 2s - loss: 0.3436 - mean_squared_error: 0.2885 - mean_absolute_error: 0.3436 - val_loss: 0.3456 - val_mean_squared_error: 0.2980 - val_mean_absolute_error: 0.3456
# Epoch 49/100
#  - 2s - loss: 0.3426 - mean_squared_error: 0.2870 - mean_absolute_error: 0.3426 - val_loss: 0.3448 - val_mean_squared_error: 0.2977 - val_mean_absolute_error: 0.3448
# Epoch 50/100
#  - 2s - loss: 0.3416 - mean_squared_error: 0.2860 - mean_absolute_error: 0.3416 - val_loss: 0.3438 - val_mean_squared_error: 0.2966 - val_mean_absolute_error: 0.3438
# Epoch 51/100
#  - 2s - loss: 0.3406 - mean_squared_error: 0.2850 - mean_absolute_error: 0.3406 - val_loss: 0.3427 - val_mean_squared_error: 0.2950 - val_mean_absolute_error: 0.3427
# Epoch 52/100
#  - 2s - loss: 0.3396 - mean_squared_error: 0.2839 - mean_absolute_error: 0.3396 - val_loss: 0.3415 - val_mean_squared_error: 0.2931 - val_mean_absolute_error: 0.3415
# Epoch 53/100
#  - 2s - loss: 0.3386 - mean_squared_error: 0.2827 - mean_absolute_error: 0.3386 - val_loss: 0.3405 - val_mean_squared_error: 0.2922 - val_mean_absolute_error: 0.3405
# Epoch 54/100
#  - 2s - loss: 0.3376 - mean_squared_error: 0.2813 - mean_absolute_error: 0.3376 - val_loss: 0.3396 - val_mean_squared_error: 0.2915 - val_mean_absolute_error: 0.3396
# Epoch 55/100
#  - 2s - loss: 0.3366 - mean_squared_error: 0.2803 - mean_absolute_error: 0.3366 - val_loss: 0.3386 - val_mean_squared_error: 0.2902 - val_mean_absolute_error: 0.3386
# Epoch 56/100
#  - 2s - loss: 0.3356 - mean_squared_error: 0.2792 - mean_absolute_error: 0.3356 - val_loss: 0.3375 - val_mean_squared_error: 0.2888 - val_mean_absolute_error: 0.3375
# Epoch 57/100
#  - 2s - loss: 0.3346 - mean_squared_error: 0.2781 - mean_absolute_error: 0.3346 - val_loss: 0.3365 - val_mean_squared_error: 0.2874 - val_mean_absolute_error: 0.3365
# Epoch 58/100
#  - 2s - loss: 0.3337 - mean_squared_error: 0.2765 - mean_absolute_error: 0.3337 - val_loss: 0.3359 - val_mean_squared_error: 0.2878 - val_mean_absolute_error: 0.3359
# Epoch 59/100
#  - 2s - loss: 0.3327 - mean_squared_error: 0.2760 - mean_absolute_error: 0.3327 - val_loss: 0.3349 - val_mean_squared_error: 0.2865 - val_mean_absolute_error: 0.3349
# Epoch 60/100
#  - 2s - loss: 0.3317 - mean_squared_error: 0.2744 - mean_absolute_error: 0.3317 - val_loss: 0.3340 - val_mean_squared_error: 0.2857 - val_mean_absolute_error: 0.3340
# Epoch 61/100
#  - 2s - loss: 0.3308 - mean_squared_error: 0.2739 - mean_absolute_error: 0.3308 - val_loss: 0.3327 - val_mean_squared_error: 0.2834 - val_mean_absolute_error: 0.3327
# Epoch 62/100
#  - 2s - loss: 0.3299 - mean_squared_error: 0.2724 - mean_absolute_error: 0.3299 - val_loss: 0.3320 - val_mean_squared_error: 0.2830 - val_mean_absolute_error: 0.3320
# Epoch 63/100
#  - 2s - loss: 0.3289 - mean_squared_error: 0.2717 - mean_absolute_error: 0.3289 - val_loss: 0.3309 - val_mean_squared_error: 0.2815 - val_mean_absolute_error: 0.3309
# Epoch 64/100
#  - 2s - loss: 0.3280 - mean_squared_error: 0.2706 - mean_absolute_error: 0.3280 - val_loss: 0.3300 - val_mean_squared_error: 0.2802 - val_mean_absolute_error: 0.3300
# Epoch 65/100
#  - 2s - loss: 0.3271 - mean_squared_error: 0.2694 - mean_absolute_error: 0.3271 - val_loss: 0.3295 - val_mean_squared_error: 0.2807 - val_mean_absolute_error: 0.3295
# Epoch 66/100
#  - 2s - loss: 0.3262 - mean_squared_error: 0.2689 - mean_absolute_error: 0.3262 - val_loss: 0.3286 - val_mean_squared_error: 0.2796 - val_mean_absolute_error: 0.3286
# Epoch 67/100
#  - 2s - loss: 0.3253 - mean_squared_error: 0.2678 - mean_absolute_error: 0.3253 - val_loss: 0.3278 - val_mean_squared_error: 0.2788 - val_mean_absolute_error: 0.3278
# Epoch 68/100
#  - 2s - loss: 0.3245 - mean_squared_error: 0.2672 - mean_absolute_error: 0.3245 - val_loss: 0.3268 - val_mean_squared_error: 0.2774 - val_mean_absolute_error: 0.3268
# Epoch 69/100
#  - 2s - loss: 0.3236 - mean_squared_error: 0.2658 - mean_absolute_error: 0.3236 - val_loss: 0.3264 - val_mean_squared_error: 0.2781 - val_mean_absolute_error: 0.3264
# Epoch 70/100
#  - 2s - loss: 0.3228 - mean_squared_error: 0.2655 - mean_absolute_error: 0.3228 - val_loss: 0.3253 - val_mean_squared_error: 0.2761 - val_mean_absolute_error: 0.3253
# Epoch 71/100
#  - 2s - loss: 0.3220 - mean_squared_error: 0.2643 - mean_absolute_error: 0.3220 - val_loss: 0.3248 - val_mean_squared_error: 0.2763 - val_mean_absolute_error: 0.3248
# Epoch 72/100
#  - 2s - loss: 0.3212 - mean_squared_error: 0.2638 - mean_absolute_error: 0.3212 - val_loss: 0.3237 - val_mean_squared_error: 0.2744 - val_mean_absolute_error: 0.3237
# Epoch 73/100
#  - 2s - loss: 0.3203 - mean_squared_error: 0.2624 - mean_absolute_error: 0.3203 - val_loss: 0.3233 - val_mean_squared_error: 0.2747 - val_mean_absolute_error: 0.3233
# Epoch 74/100
#  - 2s - loss: 0.3195 - mean_squared_error: 0.2623 - mean_absolute_error: 0.3195 - val_loss: 0.3222 - val_mean_squared_error: 0.2726 - val_mean_absolute_error: 0.3222
# Epoch 75/100
#  - 2s - loss: 0.3187 - mean_squared_error: 0.2610 - mean_absolute_error: 0.3187 - val_loss: 0.3217 - val_mean_squared_error: 0.2728 - val_mean_absolute_error: 0.3217
# Epoch 76/100
#  - 2s - loss: 0.3180 - mean_squared_error: 0.2606 - mean_absolute_error: 0.3180 - val_loss: 0.3209 - val_mean_squared_error: 0.2718 - val_mean_absolute_error: 0.3209
# Epoch 77/100
#  - 2s - loss: 0.3172 - mean_squared_error: 0.2598 - mean_absolute_error: 0.3172 - val_loss: 0.3199 - val_mean_squared_error: 0.2699 - val_mean_absolute_error: 0.3199
# Epoch 78/100
#  - 2s - loss: 0.3165 - mean_squared_error: 0.2588 - mean_absolute_error: 0.3165 - val_loss: 0.3192 - val_mean_squared_error: 0.2690 - val_mean_absolute_error: 0.3192
# Epoch 79/100
#  - 2s - loss: 0.3157 - mean_squared_error: 0.2580 - mean_absolute_error: 0.3157 - val_loss: 0.3187 - val_mean_squared_error: 0.2690 - val_mean_absolute_error: 0.3187
# Epoch 80/100
#  - 2s - loss: 0.3149 - mean_squared_error: 0.2575 - mean_absolute_error: 0.3149 - val_loss: 0.3180 - val_mean_squared_error: 0.2682 - val_mean_absolute_error: 0.3180
# Epoch 81/100
#  - 2s - loss: 0.3142 - mean_squared_error: 0.2567 - mean_absolute_error: 0.3142 - val_loss: 0.3173 - val_mean_squared_error: 0.2673 - val_mean_absolute_error: 0.3173
# Epoch 82/100
#  - 2s - loss: 0.3134 - mean_squared_error: 0.2561 - mean_absolute_error: 0.3134 - val_loss: 0.3166 - val_mean_squared_error: 0.2665 - val_mean_absolute_error: 0.3166
# Epoch 83/100
#  - 2s - loss: 0.3127 - mean_squared_error: 0.2552 - mean_absolute_error: 0.3127 - val_loss: 0.3161 - val_mean_squared_error: 0.2665 - val_mean_absolute_error: 0.3161
# Epoch 84/100
#  - 2s - loss: 0.3120 - mean_squared_error: 0.2550 - mean_absolute_error: 0.3120 - val_loss: 0.3152 - val_mean_squared_error: 0.2646 - val_mean_absolute_error: 0.3152
# Epoch 85/100
#  - 2s - loss: 0.3112 - mean_squared_error: 0.2539 - mean_absolute_error: 0.3112 - val_loss: 0.3146 - val_mean_squared_error: 0.2642 - val_mean_absolute_error: 0.3146
# Epoch 86/100
#  - 2s - loss: 0.3105 - mean_squared_error: 0.2531 - mean_absolute_error: 0.3105 - val_loss: 0.3143 - val_mean_squared_error: 0.2647 - val_mean_absolute_error: 0.3143
# Epoch 87/100
#  - 2s - loss: 0.3098 - mean_squared_error: 0.2527 - mean_absolute_error: 0.3098 - val_loss: 0.3135 - val_mean_squared_error: 0.2637 - val_mean_absolute_error: 0.3135
# Epoch 88/100
#  - 2s - loss: 0.3091 - mean_squared_error: 0.2521 - mean_absolute_error: 0.3091 - val_loss: 0.3128 - val_mean_squared_error: 0.2625 - val_mean_absolute_error: 0.3128
# Epoch 89/100
#  - 2s - loss: 0.3084 - mean_squared_error: 0.2512 - mean_absolute_error: 0.3084 - val_loss: 0.3124 - val_mean_squared_error: 0.2628 - val_mean_absolute_error: 0.3124
# Epoch 90/100
#  - 2s - loss: 0.3077 - mean_squared_error: 0.2508 - mean_absolute_error: 0.3077 - val_loss: 0.3117 - val_mean_squared_error: 0.2619 - val_mean_absolute_error: 0.3117
# Epoch 91/100
#  - 2s - loss: 0.3070 - mean_squared_error: 0.2501 - mean_absolute_error: 0.3070 - val_loss: 0.3111 - val_mean_squared_error: 0.2610 - val_mean_absolute_error: 0.3111
# Epoch 92/100
#  - 2s - loss: 0.3063 - mean_squared_error: 0.2494 - mean_absolute_error: 0.3063 - val_loss: 0.3104 - val_mean_squared_error: 0.2599 - val_mean_absolute_error: 0.3104
# Epoch 93/100
#  - 2s - loss: 0.3056 - mean_squared_error: 0.2487 - mean_absolute_error: 0.3056 - val_loss: 0.3100 - val_mean_squared_error: 0.2603 - val_mean_absolute_error: 0.3100
# Epoch 94/100
#  - 2s - loss: 0.3049 - mean_squared_error: 0.2483 - mean_absolute_error: 0.3049 - val_loss: 0.3092 - val_mean_squared_error: 0.2589 - val_mean_absolute_error: 0.3092
# Epoch 95/100
#  - 2s - loss: 0.3042 - mean_squared_error: 0.2475 - mean_absolute_error: 0.3042 - val_loss: 0.3087 - val_mean_squared_error: 0.2588 - val_mean_absolute_error: 0.3087
# Epoch 96/100
#  - 2s - loss: 0.3035 - mean_squared_error: 0.2469 - mean_absolute_error: 0.3035 - val_loss: 0.3082 - val_mean_squared_error: 0.2586 - val_mean_absolute_error: 0.3082
# Epoch 97/100
#  - 2s - loss: 0.3028 - mean_squared_error: 0.2463 - mean_absolute_error: 0.3028 - val_loss: 0.3076 - val_mean_squared_error: 0.2581 - val_mean_absolute_error: 0.3076
# Epoch 98/100
#  - 2s - loss: 0.3021 - mean_squared_error: 0.2457 - mean_absolute_error: 0.3021 - val_loss: 0.3071 - val_mean_squared_error: 0.2580 - val_mean_absolute_error: 0.3071
# Epoch 99/100
#  - 2s - loss: 0.3014 - mean_squared_error: 0.2455 - mean_absolute_error: 0.3014 - val_loss: 0.3062 - val_mean_squared_error: 0.2558 - val_mean_absolute_error: 0.3062
# Epoch 100/100
#  - 2s - loss: 0.3008 - mean_squared_error: 0.2445 - mean_absolute_error: 0.3008 - val_loss: 0.3058 - val_mean_squared_error: 0.2559 - val_mean_absolute_error: 0.3058
# Finished training model 20180917_191016!
# Found results file
# Successfully created plots and figures for model 20180917_191016
# Starting to train model 20180917_191346: bs=128, lr=0.0001, opt=gradient, lf=mae, epochs=100
# Train on 17036 samples, validate on 1909 samples
# Epoch 1/100
#  - 2s - loss: 0.3003 - mean_squared_error: 0.2441 - mean_absolute_error: 0.3003 - val_loss: 0.3056 - val_mean_squared_error: 0.2561 - val_mean_absolute_error: 0.3056
# Epoch 2/100
#  - 1s - loss: 0.3000 - mean_squared_error: 0.2440 - mean_absolute_error: 0.3000 - val_loss: 0.3052 - val_mean_squared_error: 0.2556 - val_mean_absolute_error: 0.3052
# Epoch 3/100
#  - 1s - loss: 0.2996 - mean_squared_error: 0.2437 - mean_absolute_error: 0.2996 - val_loss: 0.3050 - val_mean_squared_error: 0.2557 - val_mean_absolute_error: 0.3050
# Epoch 4/100
#  - 1s - loss: 0.2993 - mean_squared_error: 0.2436 - mean_absolute_error: 0.2993 - val_loss: 0.3047 - val_mean_squared_error: 0.2552 - val_mean_absolute_error: 0.3047
# Epoch 5/100
#  - 1s - loss: 0.2990 - mean_squared_error: 0.2432 - mean_absolute_error: 0.2990 - val_loss: 0.3043 - val_mean_squared_error: 0.2546 - val_mean_absolute_error: 0.3043
# Epoch 6/100
#  - 1s - loss: 0.2987 - mean_squared_error: 0.2430 - mean_absolute_error: 0.2987 - val_loss: 0.3040 - val_mean_squared_error: 0.2542 - val_mean_absolute_error: 0.3040
# Epoch 7/100
#  - 1s - loss: 0.2983 - mean_squared_error: 0.2425 - mean_absolute_error: 0.2983 - val_loss: 0.3039 - val_mean_squared_error: 0.2547 - val_mean_absolute_error: 0.3039
# Epoch 8/100
#  - 2s - loss: 0.2980 - mean_squared_error: 0.2425 - mean_absolute_error: 0.2980 - val_loss: 0.3036 - val_mean_squared_error: 0.2545 - val_mean_absolute_error: 0.3036
# Epoch 9/100
#  - 2s - loss: 0.2977 - mean_squared_error: 0.2424 - mean_absolute_error: 0.2977 - val_loss: 0.3033 - val_mean_squared_error: 0.2540 - val_mean_absolute_error: 0.3033
# Epoch 10/100
#  - 1s - loss: 0.2974 - mean_squared_error: 0.2420 - mean_absolute_error: 0.2974 - val_loss: 0.3030 - val_mean_squared_error: 0.2536 - val_mean_absolute_error: 0.3030
# Epoch 11/100
#  - 1s - loss: 0.2971 - mean_squared_error: 0.2416 - mean_absolute_error: 0.2971 - val_loss: 0.3028 - val_mean_squared_error: 0.2537 - val_mean_absolute_error: 0.3028
# Epoch 12/100
#  - 1s - loss: 0.2968 - mean_squared_error: 0.2416 - mean_absolute_error: 0.2968 - val_loss: 0.3025 - val_mean_squared_error: 0.2533 - val_mean_absolute_error: 0.3025
# Epoch 13/100
#  - 1s - loss: 0.2965 - mean_squared_error: 0.2414 - mean_absolute_error: 0.2965 - val_loss: 0.3021 - val_mean_squared_error: 0.2527 - val_mean_absolute_error: 0.3021
# Epoch 14/100
#  - 1s - loss: 0.2962 - mean_squared_error: 0.2410 - mean_absolute_error: 0.2962 - val_loss: 0.3020 - val_mean_squared_error: 0.2531 - val_mean_absolute_error: 0.3020
# Epoch 15/100
#  - 1s - loss: 0.2959 - mean_squared_error: 0.2409 - mean_absolute_error: 0.2959 - val_loss: 0.3017 - val_mean_squared_error: 0.2527 - val_mean_absolute_error: 0.3017
# Epoch 16/100
#  - 1s - loss: 0.2956 - mean_squared_error: 0.2407 - mean_absolute_error: 0.2956 - val_loss: 0.3014 - val_mean_squared_error: 0.2521 - val_mean_absolute_error: 0.3014
# Epoch 17/100
#  - 1s - loss: 0.2953 - mean_squared_error: 0.2403 - mean_absolute_error: 0.2953 - val_loss: 0.3012 - val_mean_squared_error: 0.2525 - val_mean_absolute_error: 0.3012
# Epoch 18/100
#  - 1s - loss: 0.2950 - mean_squared_error: 0.2403 - mean_absolute_error: 0.2950 - val_loss: 0.3009 - val_mean_squared_error: 0.2519 - val_mean_absolute_error: 0.3009
# Epoch 19/100
#  - 1s - loss: 0.2948 - mean_squared_error: 0.2399 - mean_absolute_error: 0.2948 - val_loss: 0.3007 - val_mean_squared_error: 0.2519 - val_mean_absolute_error: 0.3007
# Epoch 20/100
#  - 1s - loss: 0.2945 - mean_squared_error: 0.2398 - mean_absolute_error: 0.2945 - val_loss: 0.3004 - val_mean_squared_error: 0.2516 - val_mean_absolute_error: 0.3004
# Epoch 21/100
#  - 1s - loss: 0.2942 - mean_squared_error: 0.2396 - mean_absolute_error: 0.2942 - val_loss: 0.3003 - val_mean_squared_error: 0.2518 - val_mean_absolute_error: 0.3003
# Epoch 22/100
#  - 1s - loss: 0.2939 - mean_squared_error: 0.2395 - mean_absolute_error: 0.2939 - val_loss: 0.3000 - val_mean_squared_error: 0.2514 - val_mean_absolute_error: 0.3000
# Epoch 23/100
#  - 2s - loss: 0.2937 - mean_squared_error: 0.2392 - mean_absolute_error: 0.2937 - val_loss: 0.2998 - val_mean_squared_error: 0.2514 - val_mean_absolute_error: 0.2998
# Epoch 24/100
#  - 2s - loss: 0.2934 - mean_squared_error: 0.2392 - mean_absolute_error: 0.2934 - val_loss: 0.2994 - val_mean_squared_error: 0.2506 - val_mean_absolute_error: 0.2994
# Epoch 25/100
#  - 1s - loss: 0.2932 - mean_squared_error: 0.2387 - mean_absolute_error: 0.2932 - val_loss: 0.2993 - val_mean_squared_error: 0.2508 - val_mean_absolute_error: 0.2993
# Epoch 26/100
#  - 1s - loss: 0.2929 - mean_squared_error: 0.2387 - mean_absolute_error: 0.2929 - val_loss: 0.2991 - val_mean_squared_error: 0.2507 - val_mean_absolute_error: 0.2991
# Epoch 27/100
#  - 1s - loss: 0.2927 - mean_squared_error: 0.2387 - mean_absolute_error: 0.2927 - val_loss: 0.2988 - val_mean_squared_error: 0.2502 - val_mean_absolute_error: 0.2988
# Epoch 28/100
#  - 1s - loss: 0.2924 - mean_squared_error: 0.2384 - mean_absolute_error: 0.2924 - val_loss: 0.2986 - val_mean_squared_error: 0.2501 - val_mean_absolute_error: 0.2986
# Epoch 29/100
#  - 1s - loss: 0.2922 - mean_squared_error: 0.2383 - mean_absolute_error: 0.2922 - val_loss: 0.2983 - val_mean_squared_error: 0.2496 - val_mean_absolute_error: 0.2983
# Epoch 30/100
#  - 1s - loss: 0.2920 - mean_squared_error: 0.2378 - mean_absolute_error: 0.2920 - val_loss: 0.2984 - val_mean_squared_error: 0.2505 - val_mean_absolute_error: 0.2984
# Epoch 31/100
#  - 1s - loss: 0.2917 - mean_squared_error: 0.2381 - mean_absolute_error: 0.2917 - val_loss: 0.2979 - val_mean_squared_error: 0.2496 - val_mean_absolute_error: 0.2979
# Epoch 32/100
#  - 1s - loss: 0.2915 - mean_squared_error: 0.2376 - mean_absolute_error: 0.2915 - val_loss: 0.2978 - val_mean_squared_error: 0.2498 - val_mean_absolute_error: 0.2978
# Epoch 33/100
#  - 1s - loss: 0.2913 - mean_squared_error: 0.2375 - mean_absolute_error: 0.2913 - val_loss: 0.2979 - val_mean_squared_error: 0.2504 - val_mean_absolute_error: 0.2979
# Epoch 34/100
#  - 2s - loss: 0.2910 - mean_squared_error: 0.2377 - mean_absolute_error: 0.2910 - val_loss: 0.2976 - val_mean_squared_error: 0.2501 - val_mean_absolute_error: 0.2976
# Epoch 35/100
#  - 2s - loss: 0.2908 - mean_squared_error: 0.2375 - mean_absolute_error: 0.2908 - val_loss: 0.2973 - val_mean_squared_error: 0.2497 - val_mean_absolute_error: 0.2973
# Epoch 36/100
#  - 1s - loss: 0.2906 - mean_squared_error: 0.2373 - mean_absolute_error: 0.2906 - val_loss: 0.2971 - val_mean_squared_error: 0.2495 - val_mean_absolute_error: 0.2971
# Epoch 37/100
#  - 1s - loss: 0.2904 - mean_squared_error: 0.2371 - mean_absolute_error: 0.2904 - val_loss: 0.2971 - val_mean_squared_error: 0.2497 - val_mean_absolute_error: 0.2971
# Epoch 38/100
#  - 1s - loss: 0.2902 - mean_squared_error: 0.2370 - mean_absolute_error: 0.2902 - val_loss: 0.2969 - val_mean_squared_error: 0.2496 - val_mean_absolute_error: 0.2969
# Epoch 39/100
#  - 2s - loss: 0.2900 - mean_squared_error: 0.2369 - mean_absolute_error: 0.2900 - val_loss: 0.2966 - val_mean_squared_error: 0.2492 - val_mean_absolute_error: 0.2966
# Epoch 40/100
#  - 1s - loss: 0.2897 - mean_squared_error: 0.2367 - mean_absolute_error: 0.2897 - val_loss: 0.2965 - val_mean_squared_error: 0.2492 - val_mean_absolute_error: 0.2965
# Epoch 41/100
#  - 1s - loss: 0.2895 - mean_squared_error: 0.2367 - mean_absolute_error: 0.2895 - val_loss: 0.2961 - val_mean_squared_error: 0.2487 - val_mean_absolute_error: 0.2961
# Epoch 42/100
#  - 1s - loss: 0.2893 - mean_squared_error: 0.2364 - mean_absolute_error: 0.2893 - val_loss: 0.2960 - val_mean_squared_error: 0.2486 - val_mean_absolute_error: 0.2960
# Epoch 43/100
#  - 1s - loss: 0.2891 - mean_squared_error: 0.2362 - mean_absolute_error: 0.2891 - val_loss: 0.2959 - val_mean_squared_error: 0.2489 - val_mean_absolute_error: 0.2959
# Epoch 44/100
#  - 1s - loss: 0.2890 - mean_squared_error: 0.2363 - mean_absolute_error: 0.2890 - val_loss: 0.2957 - val_mean_squared_error: 0.2487 - val_mean_absolute_error: 0.2957
# Epoch 45/100
#  - 1s - loss: 0.2888 - mean_squared_error: 0.2360 - mean_absolute_error: 0.2888 - val_loss: 0.2954 - val_mean_squared_error: 0.2482 - val_mean_absolute_error: 0.2954
# Epoch 46/100
#  - 2s - loss: 0.2886 - mean_squared_error: 0.2358 - mean_absolute_error: 0.2886 - val_loss: 0.2954 - val_mean_squared_error: 0.2484 - val_mean_absolute_error: 0.2954
# Epoch 47/100
#  - 1s - loss: 0.2884 - mean_squared_error: 0.2359 - mean_absolute_error: 0.2884 - val_loss: 0.2950 - val_mean_squared_error: 0.2478 - val_mean_absolute_error: 0.2950
# Epoch 48/100
#  - 1s - loss: 0.2882 - mean_squared_error: 0.2357 - mean_absolute_error: 0.2882 - val_loss: 0.2948 - val_mean_squared_error: 0.2475 - val_mean_absolute_error: 0.2948
# Epoch 49/100
#  - 1s - loss: 0.2881 - mean_squared_error: 0.2353 - mean_absolute_error: 0.2881 - val_loss: 0.2948 - val_mean_squared_error: 0.2479 - val_mean_absolute_error: 0.2948
# Epoch 50/100
#  - 1s - loss: 0.2879 - mean_squared_error: 0.2352 - mean_absolute_error: 0.2879 - val_loss: 0.2950 - val_mean_squared_error: 0.2487 - val_mean_absolute_error: 0.2950
# Epoch 51/100
#  - 1s - loss: 0.2877 - mean_squared_error: 0.2355 - mean_absolute_error: 0.2877 - val_loss: 0.2946 - val_mean_squared_error: 0.2481 - val_mean_absolute_error: 0.2946
# Epoch 52/100
#  - 1s - loss: 0.2875 - mean_squared_error: 0.2352 - mean_absolute_error: 0.2875 - val_loss: 0.2943 - val_mean_squared_error: 0.2477 - val_mean_absolute_error: 0.2943
# Epoch 53/100
#  - 1s - loss: 0.2874 - mean_squared_error: 0.2350 - mean_absolute_error: 0.2874 - val_loss: 0.2944 - val_mean_squared_error: 0.2480 - val_mean_absolute_error: 0.2944
# Epoch 54/100
#  - 2s - loss: 0.2872 - mean_squared_error: 0.2351 - mean_absolute_error: 0.2872 - val_loss: 0.2939 - val_mean_squared_error: 0.2472 - val_mean_absolute_error: 0.2939
# Epoch 55/100
#  - 1s - loss: 0.2870 - mean_squared_error: 0.2347 - mean_absolute_error: 0.2870 - val_loss: 0.2937 - val_mean_squared_error: 0.2470 - val_mean_absolute_error: 0.2937
# Epoch 56/100
#  - 1s - loss: 0.2869 - mean_squared_error: 0.2346 - mean_absolute_error: 0.2869 - val_loss: 0.2937 - val_mean_squared_error: 0.2471 - val_mean_absolute_error: 0.2937
# Epoch 57/100
#  - 2s - loss: 0.2867 - mean_squared_error: 0.2346 - mean_absolute_error: 0.2867 - val_loss: 0.2935 - val_mean_squared_error: 0.2470 - val_mean_absolute_error: 0.2935
# Epoch 58/100
#  - 2s - loss: 0.2866 - mean_squared_error: 0.2344 - mean_absolute_error: 0.2866 - val_loss: 0.2933 - val_mean_squared_error: 0.2469 - val_mean_absolute_error: 0.2933
# Epoch 59/100
#  - 2s - loss: 0.2864 - mean_squared_error: 0.2344 - mean_absolute_error: 0.2864 - val_loss: 0.2931 - val_mean_squared_error: 0.2465 - val_mean_absolute_error: 0.2931
# Epoch 60/100
#  - 2s - loss: 0.2863 - mean_squared_error: 0.2340 - mean_absolute_error: 0.2863 - val_loss: 0.2931 - val_mean_squared_error: 0.2468 - val_mean_absolute_error: 0.2931
# Epoch 61/100
#  - 1s - loss: 0.2861 - mean_squared_error: 0.2341 - mean_absolute_error: 0.2861 - val_loss: 0.2927 - val_mean_squared_error: 0.2462 - val_mean_absolute_error: 0.2927
# Epoch 62/100
#  - 1s - loss: 0.2860 - mean_squared_error: 0.2337 - mean_absolute_error: 0.2860 - val_loss: 0.2927 - val_mean_squared_error: 0.2465 - val_mean_absolute_error: 0.2927
# Epoch 63/100
#  - 2s - loss: 0.2858 - mean_squared_error: 0.2338 - mean_absolute_error: 0.2858 - val_loss: 0.2927 - val_mean_squared_error: 0.2468 - val_mean_absolute_error: 0.2927
# Epoch 64/100
#  - 2s - loss: 0.2857 - mean_squared_error: 0.2339 - mean_absolute_error: 0.2857 - val_loss: 0.2926 - val_mean_squared_error: 0.2468 - val_mean_absolute_error: 0.2926
# Epoch 65/100
#  - 2s - loss: 0.2855 - mean_squared_error: 0.2338 - mean_absolute_error: 0.2855 - val_loss: 0.2922 - val_mean_squared_error: 0.2460 - val_mean_absolute_error: 0.2922
# Epoch 66/100
#  - 2s - loss: 0.2854 - mean_squared_error: 0.2334 - mean_absolute_error: 0.2854 - val_loss: 0.2921 - val_mean_squared_error: 0.2461 - val_mean_absolute_error: 0.2921
# Epoch 67/100
#  - 2s - loss: 0.2852 - mean_squared_error: 0.2336 - mean_absolute_error: 0.2852 - val_loss: 0.2918 - val_mean_squared_error: 0.2456 - val_mean_absolute_error: 0.2918
# Epoch 68/100
#  - 2s - loss: 0.2851 - mean_squared_error: 0.2331 - mean_absolute_error: 0.2851 - val_loss: 0.2919 - val_mean_squared_error: 0.2463 - val_mean_absolute_error: 0.2919
# Epoch 69/100
#  - 2s - loss: 0.2850 - mean_squared_error: 0.2333 - mean_absolute_error: 0.2850 - val_loss: 0.2917 - val_mean_squared_error: 0.2459 - val_mean_absolute_error: 0.2917
# Epoch 70/100
#  - 2s - loss: 0.2848 - mean_squared_error: 0.2331 - mean_absolute_error: 0.2848 - val_loss: 0.2915 - val_mean_squared_error: 0.2458 - val_mean_absolute_error: 0.2915
# Epoch 71/100
#  - 1s - loss: 0.2847 - mean_squared_error: 0.2331 - mean_absolute_error: 0.2847 - val_loss: 0.2913 - val_mean_squared_error: 0.2456 - val_mean_absolute_error: 0.2913
# Epoch 72/100
#  - 1s - loss: 0.2846 - mean_squared_error: 0.2328 - mean_absolute_error: 0.2846 - val_loss: 0.2912 - val_mean_squared_error: 0.2457 - val_mean_absolute_error: 0.2912
# Epoch 73/100
#  - 1s - loss: 0.2845 - mean_squared_error: 0.2329 - mean_absolute_error: 0.2845 - val_loss: 0.2910 - val_mean_squared_error: 0.2454 - val_mean_absolute_error: 0.2910
# Epoch 74/100
#  - 1s - loss: 0.2843 - mean_squared_error: 0.2327 - mean_absolute_error: 0.2843 - val_loss: 0.2909 - val_mean_squared_error: 0.2453 - val_mean_absolute_error: 0.2909
# Epoch 75/100
#  - 1s - loss: 0.2842 - mean_squared_error: 0.2326 - mean_absolute_error: 0.2842 - val_loss: 0.2908 - val_mean_squared_error: 0.2453 - val_mean_absolute_error: 0.2908
# Epoch 76/100
#  - 1s - loss: 0.2841 - mean_squared_error: 0.2326 - mean_absolute_error: 0.2841 - val_loss: 0.2906 - val_mean_squared_error: 0.2452 - val_mean_absolute_error: 0.2906
# Epoch 77/100
#  - 1s - loss: 0.2839 - mean_squared_error: 0.2324 - mean_absolute_error: 0.2839 - val_loss: 0.2906 - val_mean_squared_error: 0.2455 - val_mean_absolute_error: 0.2906
# Epoch 78/100
#  - 1s - loss: 0.2838 - mean_squared_error: 0.2325 - mean_absolute_error: 0.2838 - val_loss: 0.2903 - val_mean_squared_error: 0.2448 - val_mean_absolute_error: 0.2903
# Epoch 79/100
#  - 1s - loss: 0.2837 - mean_squared_error: 0.2323 - mean_absolute_error: 0.2837 - val_loss: 0.2902 - val_mean_squared_error: 0.2448 - val_mean_absolute_error: 0.2902
# Epoch 80/100
#  - 1s - loss: 0.2836 - mean_squared_error: 0.2322 - mean_absolute_error: 0.2836 - val_loss: 0.2901 - val_mean_squared_error: 0.2449 - val_mean_absolute_error: 0.2901
# Epoch 81/100
#  - 1s - loss: 0.2835 - mean_squared_error: 0.2322 - mean_absolute_error: 0.2835 - val_loss: 0.2898 - val_mean_squared_error: 0.2444 - val_mean_absolute_error: 0.2898
# Epoch 82/100
#  - 1s - loss: 0.2833 - mean_squared_error: 0.2319 - mean_absolute_error: 0.2833 - val_loss: 0.2900 - val_mean_squared_error: 0.2453 - val_mean_absolute_error: 0.2900
# Epoch 83/100
#  - 1s - loss: 0.2832 - mean_squared_error: 0.2321 - mean_absolute_error: 0.2832 - val_loss: 0.2898 - val_mean_squared_error: 0.2449 - val_mean_absolute_error: 0.2898
# Epoch 84/100
#  - 1s - loss: 0.2831 - mean_squared_error: 0.2321 - mean_absolute_error: 0.2831 - val_loss: 0.2894 - val_mean_squared_error: 0.2439 - val_mean_absolute_error: 0.2894
# Epoch 85/100
#  - 1s - loss: 0.2830 - mean_squared_error: 0.2317 - mean_absolute_error: 0.2830 - val_loss: 0.2894 - val_mean_squared_error: 0.2444 - val_mean_absolute_error: 0.2894
# Epoch 86/100
#  - 1s - loss: 0.2829 - mean_squared_error: 0.2317 - mean_absolute_error: 0.2829 - val_loss: 0.2892 - val_mean_squared_error: 0.2443 - val_mean_absolute_error: 0.2892
# Epoch 87/100
#  - 1s - loss: 0.2827 - mean_squared_error: 0.2316 - mean_absolute_error: 0.2827 - val_loss: 0.2893 - val_mean_squared_error: 0.2447 - val_mean_absolute_error: 0.2893
# Epoch 88/100
#  - 1s - loss: 0.2826 - mean_squared_error: 0.2316 - mean_absolute_error: 0.2826 - val_loss: 0.2892 - val_mean_squared_error: 0.2448 - val_mean_absolute_error: 0.2892
# Epoch 89/100
#  - 2s - loss: 0.2825 - mean_squared_error: 0.2317 - mean_absolute_error: 0.2825 - val_loss: 0.2889 - val_mean_squared_error: 0.2441 - val_mean_absolute_error: 0.2889
# Epoch 90/100
#  - 2s - loss: 0.2824 - mean_squared_error: 0.2314 - mean_absolute_error: 0.2824 - val_loss: 0.2888 - val_mean_squared_error: 0.2441 - val_mean_absolute_error: 0.2888
# Epoch 91/100
#  - 2s - loss: 0.2823 - mean_squared_error: 0.2312 - mean_absolute_error: 0.2823 - val_loss: 0.2889 - val_mean_squared_error: 0.2446 - val_mean_absolute_error: 0.2889
# Epoch 92/100
#  - 1s - loss: 0.2822 - mean_squared_error: 0.2313 - mean_absolute_error: 0.2822 - val_loss: 0.2886 - val_mean_squared_error: 0.2441 - val_mean_absolute_error: 0.2886
# Epoch 93/100
#  - 1s - loss: 0.2820 - mean_squared_error: 0.2313 - mean_absolute_error: 0.2820 - val_loss: 0.2884 - val_mean_squared_error: 0.2437 - val_mean_absolute_error: 0.2884
# Epoch 94/100
#  - 1s - loss: 0.2819 - mean_squared_error: 0.2309 - mean_absolute_error: 0.2819 - val_loss: 0.2883 - val_mean_squared_error: 0.2440 - val_mean_absolute_error: 0.2883
# Epoch 95/100
#  - 1s - loss: 0.2818 - mean_squared_error: 0.2310 - mean_absolute_error: 0.2818 - val_loss: 0.2882 - val_mean_squared_error: 0.2439 - val_mean_absolute_error: 0.2882
# Epoch 96/100
#  - 1s - loss: 0.2817 - mean_squared_error: 0.2310 - mean_absolute_error: 0.2817 - val_loss: 0.2881 - val_mean_squared_error: 0.2440 - val_mean_absolute_error: 0.2881
# Epoch 97/100
#  - 1s - loss: 0.2816 - mean_squared_error: 0.2310 - mean_absolute_error: 0.2816 - val_loss: 0.2882 - val_mean_squared_error: 0.2443 - val_mean_absolute_error: 0.2882
# Epoch 98/100
#  - 1s - loss: 0.2815 - mean_squared_error: 0.2311 - mean_absolute_error: 0.2815 - val_loss: 0.2878 - val_mean_squared_error: 0.2434 - val_mean_absolute_error: 0.2878
# Epoch 99/100
#  - 1s - loss: 0.2814 - mean_squared_error: 0.2306 - mean_absolute_error: 0.2814 - val_loss: 0.2879 - val_mean_squared_error: 0.2440 - val_mean_absolute_error: 0.2879
# Epoch 100/100
#  - 1s - loss: 0.2813 - mean_squared_error: 0.2311 - mean_absolute_error: 0.2813 - val_loss: 0.2874 - val_mean_squared_error: 0.2429 - val_mean_absolute_error: 0.2874
# Finished training model 20180917_191346!
# Found results file
# Successfully created plots and figures for model 20180917_191346
# Completed all training runs!

# %% [markdown]
# ### End of Script
